# %% [markdown]
# <details><summary style="display:list-item; font-size:16px; color:blue;">Jupyter Help</summary>
#
# Having trouble testing your work? Double-check that you have followed the steps below to write, run, save, and test your code!
#
# [Click here for a walkthrough GIF of the steps below](https://static-assets.codecademy.com/Courses/ds-python/jupyter-help.gif)
#
# Run all initial cells to import libraries and datasets. Then follow these steps for each question:
#
# 1. Add your solution to the cell with `## YOUR SOLUTION HERE ## `.
# 2. Run the cell by selecting the `Run` button or the `Shift`+`Enter` keys.
# 3. Save your work by selecting the `Save` button, the `command`+`s` keys (Mac), or `control`+`s` keys (Windows).
# 4. Select the `Test Work` button at the bottom left to test your work.
#
# ![Screenshot of the buttons at the top of a Jupyter Notebook. The Run and Save buttons are highlighted](https://static-assets.codecademy.com/Paths/ds-python/jupyter-buttons.png)

# %% [markdown]
# **Setup**
#
# Run the setup cell to import Chroma and Langchain's `RecursiveCharacterTextSplitter`.  The variable `files` gives us some details about the two files we will upload.

# %%
import chromadb
from langchain.text_splitter import RecursiveCharacterTextSplitter

files = [
    {
        "title": "Anthropology of Food",
        "source_url": "https://openstax.org/details/books/introduction-anthropology",
        "filename": "anthro_food.txt"
  },
  {
        "title": "Anthropology of Art, Music, and Sport",
        "source_url": "https://openstax.org/details/books/introduction-anthropology",
        "filename": "anthro_art.txt"
  }
]

# %% [markdown]
# #### Checkpoint 1/4
#
# We've initialized a Chroma client using `chromadb.PersistentClient("./")` to persist the Chroma vector database. Now, create a collection with the variable name `collection` by using the Chroma client's `get_or_create_collection()` method with the following specifications:
# - Set the `name` argument to a new collection named `"RAG_Assistant"`.
# - Set metadata parameter to specify cosine similarity as the distance metric for the HNSW index.
#
# **Don't forget to run the cell and save the notebook before selecting `Test Work`! Open the `Jupyter Help` toggle at the top of the notebook for more details.**

# %%
# Instantiate a Chroma persistent client
client = chromadb.PersistentClient("./")


## YOUR SOLUTION HERE ##
collection = client.get_or_create_collection(name="RAG_Assistant",
                                             metadata={"hnsw:space": "cosine"})

# %% [markdown]
# #### Checkpoint 2/4
# Next, we will create a text splitter instance using the `RecursiveCharacterTextSplitter()` class in LangChain. Define the instance as `text_splitter` with the following arguments:
# - `separators` set to `["\n\n", "\n", ". ", "? ", "! "]`
# - `chunk_size` set to `1500`,
# - `chunk_overlap`set to`200`.
#
# Once your text splitter is correctly defined, it will use the file in files, `anthro_food.txt`, as the content and create a list of document chunks.  The first document will be print to verify your code worked correctly.
#
# **Don't forget to run the cell and save the notebook before selecting `Test Work`! Open the `Jupyter Help` toggle at the top of the notebook for more details.**

# %%
#Read first file content
with open(f"./{files[0]['filename']}", "r") as file:
  content = file.read()


# Create a text splitter
## YOUR SOLUTION HERE ##
text_splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", ". ", "? ", "! "],
    chunk_size=1500,
    chunk_overlap=200,
)

# Split the 'content' into chunks
chunks = text_splitter.create_documents([content])

# Print the first document
chunks[:1]
# Out:
# [Document(page_content='INTRODUCTION\nCHAPTER 14\nAnthropology of Food\n14.1 Food as a Material Arti\ue005act\n14.2 A Biocultural Approach to Food\n14.3 Food and Cultural Identity\n14.4 The Globalization o\ue005 Food\nThe study o\ue005 \ue005ood has a long history in anthropology and weaves together various sub\ue061elds\no\ue005 the discipline. Among other things, \ue005ood connects to nutrition and health, rituals and behaviors regarding\nproduction and consumption, and worldwide trade networks and the related di\ue005\ue005usion o\ue005 plants, animals, and\narti\ue005acts. Distinguishing between what is and what is not \ue005ood is a major concern within and across most\nhuman cultures. Food varies not only \ue005rom one society to another but also across genders, classes, \ue005amily\ngroups, and seasons. As both a source o\ue005 sustenance \ue005or the body and a means o\ue005 establishing or advertising\none’s social status, \ue005ood plays a major role in personal and cultural identity. In globalized Western culture,\npeople regularly eat \ue005oods that originated in other cultures—such as sushi, gyros, tacos, spaghetti, and crepes,\nto name just a \ue005ew—but practices such as avoiding certain \ue005oods (\ue005ood prohibitions) and even eating one’s\nFigure 14.1\nA \ue005ruit and vegetable vendor in Saigon, Vietnam. How many o\ue005 these \ue005oods do you recognize? (credit:\n“Vietnam Sept 2012 3432 Market, Sa Dec, Viet Nam” by Lynda/\ue005lickr, CC BY 2.0)\nCHAPTER OUTLINE')]

# %% [markdown]
# #### Checkpoint 3/4
#
# Now, you'll loop through each file, create chunks from the text splitter, and upload each to Chroma. Three empty lists are instantiated, which hold information about each document:
# - `documents` and `ids` are lists of strings holding the text and a unique identifier.
# - `metadata` is a list of dictionaries which can hold metadata about each document, like the title, chunk index, and source URL.
#
# We've already written the loop for this that appends the retrieved metadata and indices. Use the `page_content` attribute to append to `documents` within the loop.
#
#
# **Don't forget to run the cell and save the notebook before selecting `Test Work`! Open the `Jupyter Help` toggle at the top of the notebook for more details.**

# %%
#Create empty lists to store each document, metadata, and id
documents = []
metadatas = []
ids = []

#Loop through each file in files
for file_info in files:
    with open(f"./{file_info['filename']}", "r") as file:
        content = file.read()
        #Use text_splitter to create documents
        chunks = text_splitter.create_documents([content])
        #iterate over every chunk
        for index, chunk in enumerate(chunks):
            #Append to metadata list with "title", "source_url", and "index"
            metadatas.append({
                "title": file_info["title"],
                "source_url": file_info["source_url"],
                "chunk_idx": index
            })
            #Append to ids each index
            ids.append(f"{file_info['filename']}_{index}")
            
            #Append to documents each chunk.page_content
            ### YOUR SOLUTION HERE ###
            documents.append(chunk.page_content)

# %% [markdown]
# #### Checkpoint 4/4
#
# Finally, pass to `.query()` a question about art or food in anthropology to verify that the database successfully accepted the chunks.
#
# **Don't forget to run the cell and save the notebook before selecting `Test Work`! Open the `Jupyter Help` toggle at the top of the notebook for more details.**

# %%
#Add all documents to the collection
collection.add(documents=documents, metadatas=metadatas, ids=ids)

#Verify documents were added to collection with a sample query
### YOUR SOLUTION HERE ###
collection.query(query_texts=["Who was Zora Neale Hurston?", "Who invented the Paleo diet?" ], n_results=1)
# Out:
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Add of existing embedding ID: anthro_food.txt_0
# Add of existing embedding ID: anthro_food.txt_1
# Add of existing embedding ID: anthro_food.txt_2
# Add of existing embedding ID: anthro_food.txt_3
# Add of existing embedding ID: anthro_food.txt_4
# Add of existing embedding ID: anthro_food.txt_5
# Add of existing embedding ID: anthro_food.txt_6
# Add of existing embedding ID: anthro_food.txt_7
# Add of existing embedding ID: anthro_food.txt_8
# Add of existing embedding ID: anthro_food.txt_9
# Add of existing embedding ID: anthro_food.txt_10
# Add of existing embedding ID: anthro_food.txt_11
# Add of existing embedding ID: anthro_food.txt_12
# Add of existing embedding ID: anthro_food.txt_13
# Add of existing embedding ID: anthro_food.txt_14
# Add of existing embedding ID: anthro_food.txt_15
# Add of existing embedding ID: anthro_food.txt_16
# Add of existing embedding ID: anthro_food.txt_17
# Add of existing embedding ID: anthro_food.txt_18
# Add of existing embedding ID: anthro_food.txt_19
# Add of existing embedding ID: anthro_food.txt_20
# Add of existing embedding ID: anthro_food.txt_21
# Add of existing embedding ID: anthro_food.txt_22
# Add of existing embedding ID: anthro_food.txt_23
# Add of existing embedding ID: anthro_food.txt_24
# Add of existing embedding ID: anthro_food.txt_25
# Add of existing embedding ID: anthro_food.txt_26
# Add of existing embedding ID: anthro_food.txt_27
# Add of existing embedding ID: anthro_food.txt_28
# Add of existing embedding ID: anthro_food.txt_29
# Add of existing embedding ID: anthro_food.txt_30
# Add of existing embedding ID: anthro_food.txt_31
# Add of existing embedding ID: anthro_food.txt_32
# Add of existing embedding ID: anthro_food.txt_33
# Add of existing embedding ID: anthro_food.txt_34
# Add of existing embedding ID: anthro_food.txt_35
# Add of existing embedding ID: anthro_food.txt_36
# Add of existing embedding ID: anthro_food.txt_37
# Add of existing embedding ID: anthro_food.txt_38
# Add of existing embedding ID: anthro_food.txt_39
# Add of existing embedding ID: anthro_food.txt_40
# Add of existing embedding ID: anthro_food.txt_41
# Add of existing embedding ID: anthro_food.txt_42
# Add of existing embedding ID: anthro_food.txt_43
# Add of existing embedding ID: anthro_food.txt_44
# Add of existing embedding ID: anthro_food.txt_45
# Add of existing embedding ID: anthro_food.txt_46
# Add of existing embedding ID: anthro_food.txt_47
# Add of existing embedding ID: anthro_food.txt_48
# Add of existing embedding ID: anthro_food.txt_49
# Add of existing embedding ID: anthro_food.txt_50
# Add of existing embedding ID: anthro_food.txt_51
# Add of existing embedding ID: anthro_food.txt_52
# Add of existing embedding ID: anthro_food.txt_53
# Add of existing embedding ID: anthro_food.txt_54
# Add of existing embedding ID: anthro_food.txt_55
# Add of existing embedding ID: anthro_food.txt_56
# Add of existing embedding ID: anthro_food.txt_57
# Add of existing embedding ID: anthro_food.txt_58
# Add of existing embedding ID: anthro_food.txt_59
# Add of existing embedding ID: anthro_food.txt_60
# Add of existing embedding ID: anthro_food.txt_61
# Add of existing embedding ID: anthro_food.txt_62
# Add of existing embedding ID: anthro_food.txt_63
# Add of existing embedding ID: anthro_food.txt_64
# Add of existing embedding ID: anthro_food.txt_65
# Add of existing embedding ID: anthro_food.txt_66
# Add of existing embedding ID: anthro_food.txt_67
# Add of existing embedding ID: anthro_food.txt_68
# Add of existing embedding ID: anthro_food.txt_69
# Add of existing embedding ID: anthro_food.txt_70
# Add of existing embedding ID: anthro_food.txt_71
# Add of existing embedding ID: anthro_food.txt_72
# Add of existing embedding ID: anthro_food.txt_73
# Add of existing embedding ID: anthro_food.txt_74
# Add of existing embedding ID: anthro_food.txt_75
# Add of existing embedding ID: anthro_food.txt_76
# Add of existing embedding ID: anthro_food.txt_77
# Add of existing embedding ID: anthro_art.txt_0
# Add of existing embedding ID: anthro_art.txt_1
# Add of existing embedding ID: anthro_art.txt_2
# Add of existing embedding ID: anthro_art.txt_3
# Add of existing embedding ID: anthro_art.txt_4
# Add of existing embedding ID: anthro_art.txt_5
# Add of existing embedding ID: anthro_art.txt_6
# Add of existing embedding ID: anthro_art.txt_7
# Add of existing embedding ID: anthro_art.txt_8
# Add of existing embedding ID: anthro_art.txt_9
# Add of existing embedding ID: anthro_art.txt_10
# Add of existing embedding ID: anthro_art.txt_11
# Add of existing embedding ID: anthro_art.txt_12
# Add of existing embedding ID: anthro_art.txt_13
# Add of existing embedding ID: anthro_art.txt_14
# Add of existing embedding ID: anthro_art.txt_15
# Add of existing embedding ID: anthro_art.txt_16
# Add of existing embedding ID: anthro_art.txt_17
# Add of existing embedding ID: anthro_art.txt_18
# Add of existing embedding ID: anthro_art.txt_19
# Add of existing embedding ID: anthro_art.txt_20
# Add of existing embedding ID: anthro_art.txt_21
# Add of existing embedding ID: anthro_art.txt_22
# Add of existing embedding ID: anthro_art.txt_23
# Add of existing embedding ID: anthro_art.txt_24
# Add of existing embedding ID: anthro_art.txt_25
# Add of existing embedding ID: anthro_art.txt_26
# Add of existing embedding ID: anthro_art.txt_27
# Add of existing embedding ID: anthro_art.txt_28
# Add of existing embedding ID: anthro_art.txt_29
# Add of existing embedding ID: anthro_art.txt_30
# Add of existing embedding ID: anthro_art.txt_31
# Add of existing embedding ID: anthro_art.txt_32
# Add of existing embedding ID: anthro_art.txt_33
# Add of existing embedding ID: anthro_art.txt_34
# Add of existing embedding ID: anthro_art.txt_35
# Add of existing embedding ID: anthro_art.txt_36
# Add of existing embedding ID: anthro_art.txt_37
# Add of existing embedding ID: anthro_art.txt_38
# Add of existing embedding ID: anthro_art.txt_39
# Add of existing embedding ID: anthro_art.txt_40
# Add of existing embedding ID: anthro_art.txt_41
# Add of existing embedding ID: anthro_art.txt_42
# Add of existing embedding ID: anthro_art.txt_43
# Add of existing embedding ID: anthro_art.txt_44
# Add of existing embedding ID: anthro_art.txt_45
# Add of existing embedding ID: anthro_art.txt_46
# Add of existing embedding ID: anthro_art.txt_47
# Add of existing embedding ID: anthro_art.txt_48
# Add of existing embedding ID: anthro_art.txt_49
# Add of existing embedding ID: anthro_art.txt_50
# Add of existing embedding ID: anthro_art.txt_51
# Add of existing embedding ID: anthro_art.txt_52
# Add of existing embedding ID: anthro_art.txt_53
# Add of existing embedding ID: anthro_art.txt_54
# Add of existing embedding ID: anthro_art.txt_55
# Add of existing embedding ID: anthro_art.txt_56
# Add of existing embedding ID: anthro_art.txt_57
# Add of existing embedding ID: anthro_art.txt_58
# Add of existing embedding ID: anthro_art.txt_59
# Add of existing embedding ID: anthro_art.txt_60
# Add of existing embedding ID: anthro_art.txt_61
# Add of existing embedding ID: anthro_art.txt_62
# Add of existing embedding ID: anthro_art.txt_63
# Add of existing embedding ID: anthro_art.txt_64
# Add of existing embedding ID: anthro_art.txt_65
# Add of existing embedding ID: anthro_art.txt_66
# Add of existing embedding ID: anthro_art.txt_67
# Add of existing embedding ID: anthro_art.txt_68
# Add of existing embedding ID: anthro_art.txt_69
# Insert of existing embedding ID: anthro_food.txt_0
# Insert of existing embedding ID: anthro_food.txt_1
# Insert of existing embedding ID: anthro_food.txt_2
# Insert of existing embedding ID: anthro_food.txt_3
# Insert of existing embedding ID: anthro_food.txt_4
# Insert of existing embedding ID: anthro_food.txt_5
# Insert of existing embedding ID: anthro_food.txt_6
# Insert of existing embedding ID: anthro_food.txt_7
# Insert of existing embedding ID: anthro_food.txt_8
# Insert of existing embedding ID: anthro_food.txt_9
# Insert of existing embedding ID: anthro_food.txt_10
# Insert of existing embedding ID: anthro_food.txt_11
# Insert of existing embedding ID: anthro_food.txt_12
# Insert of existing embedding ID: anthro_food.txt_13
# Insert of existing embedding ID: anthro_food.txt_14
# Insert of existing embedding ID: anthro_food.txt_15
# Insert of existing embedding ID: anthro_food.txt_16
# Insert of existing embedding ID: anthro_food.txt_17
# Insert of existing embedding ID: anthro_food.txt_18
# Insert of existing embedding ID: anthro_food.txt_19
# Insert of existing embedding ID: anthro_food.txt_20
# Insert of existing embedding ID: anthro_food.txt_21
# Insert of existing embedding ID: anthro_food.txt_22
# Insert of existing embedding ID: anthro_food.txt_23
# Insert of existing embedding ID: anthro_food.txt_24
# Insert of existing embedding ID: anthro_food.txt_25
# Insert of existing embedding ID: anthro_food.txt_26
# Insert of existing embedding ID: anthro_food.txt_27
# Insert of existing embedding ID: anthro_food.txt_28
# Insert of existing embedding ID: anthro_food.txt_29
# Insert of existing embedding ID: anthro_food.txt_30
# Insert of existing embedding ID: anthro_food.txt_31
# Insert of existing embedding ID: anthro_food.txt_32
# Insert of existing embedding ID: anthro_food.txt_33
# Insert of existing embedding ID: anthro_food.txt_34
# Insert of existing embedding ID: anthro_food.txt_35
# Insert of existing embedding ID: anthro_food.txt_36
# Insert of existing embedding ID: anthro_food.txt_37
# Insert of existing embedding ID: anthro_food.txt_38
# Insert of existing embedding ID: anthro_food.txt_39
# Insert of existing embedding ID: anthro_food.txt_40
# Insert of existing embedding ID: anthro_food.txt_41
# Insert of existing embedding ID: anthro_food.txt_42
# Insert of existing embedding ID: anthro_food.txt_43
# Insert of existing embedding ID: anthro_food.txt_44
# Insert of existing embedding ID: anthro_food.txt_45
# Insert of existing embedding ID: anthro_food.txt_46
# Insert of existing embedding ID: anthro_food.txt_47
# Insert of existing embedding ID: anthro_food.txt_48
# Insert of existing embedding ID: anthro_food.txt_49
# Insert of existing embedding ID: anthro_food.txt_50
# Insert of existing embedding ID: anthro_food.txt_51
# Insert of existing embedding ID: anthro_food.txt_52
# Insert of existing embedding ID: anthro_food.txt_53
# Insert of existing embedding ID: anthro_food.txt_54
# Insert of existing embedding ID: anthro_food.txt_55
# Insert of existing embedding ID: anthro_food.txt_56
# Insert of existing embedding ID: anthro_food.txt_57
# Insert of existing embedding ID: anthro_food.txt_58
# Insert of existing embedding ID: anthro_food.txt_59
# Insert of existing embedding ID: anthro_food.txt_60
# Insert of existing embedding ID: anthro_food.txt_61
# Insert of existing embedding ID: anthro_food.txt_62
# Insert of existing embedding ID: anthro_food.txt_63
# Insert of existing embedding ID: anthro_food.txt_64
# Insert of existing embedding ID: anthro_food.txt_65
# Insert of existing embedding ID: anthro_food.txt_66
# Insert of existing embedding ID: anthro_food.txt_67
# Insert of existing embedding ID: anthro_food.txt_68
# Insert of existing embedding ID: anthro_food.txt_69
# Insert of existing embedding ID: anthro_food.txt_70
# Insert of existing embedding ID: anthro_food.txt_71
# Insert of existing embedding ID: anthro_food.txt_72
# Insert of existing embedding ID: anthro_food.txt_73
# Insert of existing embedding ID: anthro_food.txt_74
# Insert of existing embedding ID: anthro_food.txt_75
# Insert of existing embedding ID: anthro_food.txt_76
# Insert of existing embedding ID: anthro_food.txt_77
# Insert of existing embedding ID: anthro_art.txt_0
# Insert of existing embedding ID: anthro_art.txt_1
# Insert of existing embedding ID: anthro_art.txt_2
# Insert of existing embedding ID: anthro_art.txt_3
# Insert of existing embedding ID: anthro_art.txt_4
# Insert of existing embedding ID: anthro_art.txt_5
# Insert of existing embedding ID: anthro_art.txt_6
# Insert of existing embedding ID: anthro_art.txt_7
# Insert of existing embedding ID: anthro_art.txt_8
# Insert of existing embedding ID: anthro_art.txt_9
# Insert of existing embedding ID: anthro_art.txt_10
# Insert of existing embedding ID: anthro_art.txt_11
# Insert of existing embedding ID: anthro_art.txt_12
# Insert of existing embedding ID: anthro_art.txt_13
# Insert of existing embedding ID: anthro_art.txt_14
# Insert of existing embedding ID: anthro_art.txt_15
# Insert of existing embedding ID: anthro_art.txt_16
# Insert of existing embedding ID: anthro_art.txt_17
# Insert of existing embedding ID: anthro_art.txt_18
# Insert of existing embedding ID: anthro_art.txt_19
# Insert of existing embedding ID: anthro_art.txt_20
# Insert of existing embedding ID: anthro_art.txt_21
# Insert of existing embedding ID: anthro_art.txt_22
# Insert of existing embedding ID: anthro_art.txt_23
# Insert of existing embedding ID: anthro_art.txt_24
# Insert of existing embedding ID: anthro_art.txt_25
# Insert of existing embedding ID: anthro_art.txt_26
# Insert of existing embedding ID: anthro_art.txt_27
# Insert of existing embedding ID: anthro_art.txt_28
# Insert of existing embedding ID: anthro_art.txt_29
# Insert of existing embedding ID: anthro_art.txt_30
# Insert of existing embedding ID: anthro_art.txt_31
# Insert of existing embedding ID: anthro_art.txt_32
# Insert of existing embedding ID: anthro_art.txt_33
# Insert of existing embedding ID: anthro_art.txt_34
# Insert of existing embedding ID: anthro_art.txt_35
# Insert of existing embedding ID: anthro_art.txt_36
# Insert of existing embedding ID: anthro_art.txt_37
# Insert of existing embedding ID: anthro_art.txt_38
# Insert of existing embedding ID: anthro_art.txt_39
# Insert of existing embedding ID: anthro_art.txt_40
# Insert of existing embedding ID: anthro_art.txt_41
# Insert of existing embedding ID: anthro_art.txt_42
# Insert of existing embedding ID: anthro_art.txt_43
# Insert of existing embedding ID: anthro_art.txt_44
# Insert of existing embedding ID: anthro_art.txt_45
# Insert of existing embedding ID: anthro_art.txt_46
# Insert of existing embedding ID: anthro_art.txt_47
# Insert of existing embedding ID: anthro_art.txt_48
# Insert of existing embedding ID: anthro_art.txt_49
# Insert of existing embedding ID: anthro_art.txt_50
# Insert of existing embedding ID: anthro_art.txt_51
# Insert of existing embedding ID: anthro_art.txt_52
# Insert of existing embedding ID: anthro_art.txt_53
# Insert of existing embedding ID: anthro_art.txt_54
# Insert of existing embedding ID: anthro_art.txt_55
# Insert of existing embedding ID: anthro_art.txt_56
# Insert of existing embedding ID: anthro_art.txt_57
# Insert of existing embedding ID: anthro_art.txt_58
# Insert of existing embedding ID: anthro_art.txt_59
# Insert of existing embedding ID: anthro_art.txt_60
# Insert of existing embedding ID: anthro_art.txt_61
# Insert of existing embedding ID: anthro_art.txt_62
# Insert of existing embedding ID: anthro_art.txt_63
# Insert of existing embedding ID: anthro_art.txt_64
# Insert of existing embedding ID: anthro_art.txt_65
# Insert of existing embedding ID: anthro_art.txt_66
# Insert of existing embedding ID: anthro_art.txt_67
# Insert of existing embedding ID: anthro_art.txt_68
# Insert of existing embedding ID: anthro_art.txt_69
# {'ids': [['anthro_art.txt_32'], ['anthro_food.txt_31']],
#  'distances': [[0.330166194149216], [0.30169785022735596]],
#  'metadatas': [[{'chunk_idx': 32,
#     'source_url': 'https://openstax.org/details/books/introduction-anthropology',
#     'title': 'Anthropology of Art, Music, and Sport'}],
#   [{'chunk_idx': 31,
#     'source_url': 'https://openstax.org/details/books/introduction-anthropology',
#     'title': 'Anthropology of Food'}]],
#  'embeddings': None,
#  'documents': [['PROFILES IN ANTHROPOLOGY\nZora Neale Hurston\n1861–1960\nFIGURE 16.15\nIn this image, Zora Neale Hurston exuberantly plays a traditional drum. (credit: “Zora Hurston, Hal\ue005-\nLength Portrait, Standing, Facing Slightly Le\ue005t, Beating the Hountar, or Mama Drum” by New York World-Telegram &\nSun sta\ue005\ue005 photographer/Library o\ue005 Congress, Public Domain)\nPersonal History: Zora Neale Hurston was a Black American anthropologist, author, and \ue061lmmaker. She was\nborn in Notasulga, Alabama, to a sharecropper turned carpenter and a \ue005ormer schoolteacher. All o\ue005 her\ngrandparents were born enslaved. Hurston moved to Eatonville, Florida, an all-Black town, in 1892, at the age\no\ue005 two. She o\ue005ten re\ue005erenced Eatonville as her home, as she had no recollection o\ue005 her time in Alabama. She\nlived in Eatonville until 1904, when her mother passed. At the time, Eatonville was a well-established Black\ncommunity with a booming economy. According to multiple accounts, Hurston was never indoctrinated into\n\ue005eeling racial in\ue005eriority. While she was a resident, her \ue005ather was elected mayor o\ue005 the town. All the shop\nowners and government o\ue005\ue061cials were also Black American elites. In adulthood, Huston o\ue005ten used Eatonville\nas the setting o\ue005 her stories.\nHuston le\ue005t Eatonville due to a poor relationship with her stepmother. She enrolled in classes at Morgan College\nin Maryland, lying about her age o\ue005 26 to be eligible \ue005or a \ue005ree high school education. She graduated in 1918'],
#   ['FIGURE 14.8\nThe paleo diet is based on contemporary ideas o\ue005 how our hunting and gathering ancestors might\nhave eaten. It includes lean meats, \ue005ruits, vegetables, and nuts. Here, the meat kabobs are lying on a bed o\ue005\nvegetables. (credit: “IMG_0308.JPG” by Michael Arrington/\ue005lickr, CC BY 2.0)\nAnother very popular diet today, based partially on cultural and nutritional studies, is the paleo diet,\nsometimes called the Paleolithic diet, the caveman diet, or the Stone Age diet. This diet was \ue061rst developed in\nthe 1970s by gastroenterologist Walter Voegtlin, who argued that our bodies (and our digestive systems) have\nbeen evolutionarily designed \ue005or a hunting-and-gathering way o\ue005 li\ue005e. The paleo diet is made up o\ue005 \ue005oods that\nare traditionally associated with this hunting-and-gathering li\ue005estyle—\ue005ruits, vegetables, lean meats, \ue061sh, nuts,\nand seeds. The Mayo Clinic, one o\ue005 the best-known US medical research centers, describes the paleo diet in\nthis way:\nThe aim o\ue005 a paleo diet is to return to a way o\ue005 eating that’s more like what early humans ate. The diet’s\nreasoning is that the human body is genetically mismatched to the modern diet that emerged with\n\ue005arming practices—an idea known as the discordance hypothesis. (Mayo Clinic Sta\ue005\ue005 2020, under\n“Purpose”)\nBiological anthropologists have done signi\ue061cant research on the \ue005oodways o\ue005 Paleolithic-era people across\ndi\ue005\ue005erent geographical areas. A great deal can be determined about what these early people likely ate using']],
#  'uris': None,
#  'data': None}

# %% [markdown]
# <details><summary style="display:list-item; font-size:16px; color:blue;"> Notice anything interesting? </summary>
#
# Notice that the results are returned as a dictionary and the cosine similarities for each result is also returned with the key `distances`.
# Consider experimenting with different queries and parameters and notice the change in your results. For example, how close (or far) are your results for unrelated queries?

# %% [markdown]
# Great job, we've solidified our knowledge by creating a persistent Chroma database, added documents, and queried the results -- we are ready to integrate these results within our Streamlit app!
